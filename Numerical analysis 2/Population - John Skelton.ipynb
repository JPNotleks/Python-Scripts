# %%
# %matplotlib inline
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def pop(y,t,a,E):
    return a*y*(1-y/E)

t=np.linspace(0,100,101)
y=odeint(pop,[10],t,args=(0.1,100))

fig=plt.figure()
plt.plot(t,y[:,0],color='blue')
