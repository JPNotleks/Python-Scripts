# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

pol=[1,1,1,1,1,1,1]
dpol=[0,6,5,4,3,2,0]
roots=np.roots(pol)
size=600

def f(x):
    return np.polyval(pol,x)

def g(x):
    return np.polyval(dpol,x)

def close(x):
    v=np.full(x.shape, False, dtype=bool)
    for i in range(roots.size):
        v[np.absolute(x-roots[i])<0.1]=True
    return v

fig=plt.figure(figsize=(12,12))

grid=np.tile(np.linspace(-0.5,0.5,num=size,dtype=complex),(size,1))+np.transpose(np.tile(np.linspace(0.5,1.5,num=size,dtype=complex),(size,1)))*1j

ind=np.zeros(grid.shape)

for i in range(16):
    grid-=f(grid)/g(grid)
    ind[np.logical_and(close(grid),ind==0)]=i
    ind[np.absolute(grid)>100000]=17
    grid[ind==17]=0

ind[ind==17]=0

a=plt.imshow(ind,cmap='inferno',origin='lower',interpolation='hermite')
